# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import date
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 584

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=metric&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | afaahiti
# Processing Record 2 of Set 1 | madzhalis
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | baardheere
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | fort bragg
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | saldanha
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | waitangi
# Processing Record 12 of Set 1 | amga
# Processing Record 13 of Set 1 | adamstown
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | puerto natales
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | kargil
# Processing Record 18 of Set 1 | fisterra
# Processing Record 19 of Set 1 | bilibino
# Processing Record 20 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 21 of Set 1 | yarmouth
# Processing Record 22 of Set 1 | port mathurin
# Processing Record 23 of Set 1 | machico
# Processing Record 24 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 1 | olonkinbyen
# Processing Record 26 of Set 1 | newman
# Processing Record 27 of Set 1 | la mira
# Processing Record 28 of Set 1 | chibougamau
# Processing Record 29 of Set 1 | savastepe
# Processing Record 30 of Set 1 | talnakh
# Processing Record 31 of Set 1 | fale old settlement
# Processing Record 32 of Set 1 | kailua-kona
# Processing Record 33 of Set 1 | sa'dah
# Processing Record 34 of Set 1 | loango
# Processing Record 35 of Set 1 | sola
# Processing Record 36 of Set 1 | invercargill
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | mandiana
# Processing Record 39 of Set 1 | happy valley-goose bay
# Processing Record 40 of Set 1 | kampene
# Processing Record 41 of Set 1 | hawaiian paradise park
# Processing Record 42 of Set 1 | weno
# Processing Record 43 of Set 1 | iskateley
# Processing Record 44 of Set 1 | cidade velha
# Processing Record 45 of Set 1 | plastun
# Processing Record 46 of Set 1 | al kharijah
# Processing Record 47 of Set 1 | lake havasu city
# Processing Record 48 of Set 1 | hammerfest
# Processing Record 49 of Set 1 | nemuro
# Processing Record 50 of Set 1 | kalevala
# Processing Record 1 of Set 2 | chinde
# Processing Record 2 of Set 2 | ust-nera
# Processing Record 3 of Set 2 | st. john's
# Processing Record 4 of Set 2 | namibe
# Processing Record 5 of Set 2 | vadso
# Processing Record 6 of Set 2 | keflavik
# Processing Record 7 of Set 2 | kavieng
# Processing Record 8 of Set 2 | kasane
# Processing Record 9 of Set 2 | yuxi
# Processing Record 10 of Set 2 | saipan
# Processing Record 11 of Set 2 | longyearbyen
# Processing Record 12 of Set 2 | cobija
# Processing Record 13 of Set 2 | utrik
# Processing Record 14 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 15 of Set 2 | guerrero negro
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | kidal
# Processing Record 18 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 19 of Set 2 | saint-joseph
# Processing Record 20 of Set 2 | tralee
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | chake chake
# Processing Record 23 of Set 2 | la passe
# Processing Record 24 of Set 2 | vila franca do campo
# Processing Record 25 of Set 2 | vilyuysk
# Processing Record 26 of Set 2 | tura
# Processing Record 27 of Set 2 | lata
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | sunne
# Processing Record 30 of Set 2 | kayangel
# Processing Record 31 of Set 2 | paka
# Processing Record 32 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record
# Processing Record 3 of Set 4 | nova vicosa
# Processing Record 4 of Set 4 | champerico
# Processing Record 5 of Set 4 | yen vinh
# Processing Record 6 of Set 4 | puerto aysen
# Processing Record 7 of Set 4 | anadyr
# Processing Record 8 of Set 4 | lihue
# Processing Record 9 of Set 4 | nuku'alofa
# Processing Record 10 of Set 4 | lyantor
# Processing Record 11 of Set 4 | pustoshka
# Processing Record 12 of Set 4 | paragould
# Processing Record 13 of Set 4 | las khorey
# Processing Record 14 of Set 4 | princeville
# Processing Record 15 of Set 4 | avarua
# Processing Record 16 of Set 4 | selkirk
# Processing Record 17 of Set 4 | gaspe
# Processing Record 18 of Set 4 | qamdo
# Processing Record 19 of Set 4 | labrador city
# Processing Record 20 of Set 4 | mazatlan
# Processing Record 21 of Set 4 | ebon
# Processing Record 22 of Set 4 | hamilton
# Processing Record 23 of Set 4 | georgetown
# Processing Record 24 of Set 4 | rosetta
# Processing Record 25 of Set 4 | dudinka
# Processing Record 26 of Set 4 | boma
# Processing Record 27 of Set 4 | sechura
# Processing Record 28 of Set 4 | kenai
# Processing Record 29 of Set 4 | freetown
# Processing Record 30 of Set 4 | broken hill
# Processing Record 31 of Set 4 | kapa'a
# Processing Record 32 of Set 4 | cold lake
# Processing Record 33 of Set 4 | verkhnevilyuysk
# Processing Record 34 of Set 4 | west island
# Processing Record 35 of Set 4 | shuangcheng
# Processing Record 36 of Set 4 | kingston
# Processing Record 37 of Set 4 | ebaye
# Processing Record 38 of Set 4 | qaqortoq
# Processing Record 39 of Set 4 | jamestown
# Processing Record 40 of Set 4 | barwala
# Processing Record 41 of Set 4 | chokwe
# Processing Record 42 of Set 4 | rexburg
# Processing Record 43 of Set 4 | stanley
# Processing Record 44 of Set 4 | oakham
# Processing Record 45 of Set 4 | amble
# Processing Record 46 of Set 4 | mount pearl
# Processing Record 47 of Set 4 | sumbe
# Processing Record 48 of Set 4 | mahanoro
# Processing Record 49 of Set 4 | batticaloa
# Processing Record 50 of Set 4 | kalibo (poblacion)
# Processing Record 1 of Set 5 | laojunmiao
# Processing Record 2 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 3 of Set 5 | muynoq
# Processing Record 4 of Set 5 | la toma
# Processing Record 5 of Set 5 | jinchang
# Processing Record 6 of Set 5 | laascaanood
# Processing Record 7 of Set 5 | mejit
# Processing Record 8 of Set 5 | barcelos
# Processing Record 9 of Set 5 | lewistown
# Processing Record 10 of Set 5 | adrar
# Processing Record 11 of Set 5 | saint-pierre
# Processing Record 12 of Set 5 | isafjordur
# Processing Record 13 of Set 5 | sarmiento
# Processing Record 14 of Set 5 | marquette
# Processing Record 15 of Set 5 | solleftea
# Processing Record 16 of Set 5 | tazovsky
# Processing Record 17 of Set 5 | kingscliff
# Processing Record 18 of Set 5 | hede
# Processing Record 19 of Set 5 | arawa
# Processing Record 20 of Set 5 | richards bay
# Processing Record 21 of Set 5 | quellon
# Processing Record 22 of Set 5 | uturoa
# Processing Record 23 of Set 5 | sanming
# Processing Record 24 of Set 5 | qaisumah
# Processing Record 25 of Set 5 | sarrebourg
# Processing Record 26 of Set 5 | macapa
# Processing Record 27 of Set 5 | fortaleza
# Processing Record 28 of Set 5 | nagqu
# Processing Record 29 of Set 5 | amalapuram
# Processing Record 30 of Set 5 | oman smart future city
# City not found. Skipping...
# Processing Record 31 of Set 5 | den burg
# Processing Record 32 of Set 5 | kapuskasing
# Processing Record 33 of Set 5 | polyarnyy
# Processing Record 34 of Set 5 | portland
# Processing Record 35 of Set 5 | sur
# Processing Record 36 of Set 5 | black point
# Processing Record 37 of Set 5 | prince rupert
# Processing Record 38 of Set 5 | ambovombe
# Processing Record 39 of Set 5 | linxia chengguanzhen
# Processing Record 40 of Set 5 | yuzhno-kurilsk
# Processing Record 41 of Set 5 | mhamid
# Processing Record 42 of Set 5 | el calafate
# Processing Record 43 of Set 5 | ulladulla
# Processing Record 44 of Set 5 | praya
# Processing Record 45 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 46 of Set 5 | mahibadhoo
# Processing Record 47 of Set 5 | concepcion
# Processing Record 48 of Set 5 | challapata
# Processing Record 49 of Set 5 | sinabang
# Processing Record 50 of Set 5 | enewetak
# Processing Record 1 of Set 6 | castillos
# Processing Record 2 of Set 6 | oltinko'l
# Processing Record 3 of Set 6 | duluth
# Processing Record 4 of Set 6 | okhotsk
# Processing Record 5 of Set 6 | nueva palestina
# Processing Record 6 of Set 6 | hilo
# Processing Record 7 of Set 6 | hermanus
# Processing Record 8 of Set 6 | calvinia
# Processing Record 9 of Set 6 | ketchikan
# Processing Record 10 of Set 6 | pertek
# Processing Record 11 of Set 6 | siwa oasis
# Processing Record 12 of Set 6 | kiama
# Processing Record 13 of Set 6 | dogubayazit
# Processing Record 14 of Set 6 | colonia
# Processing Record 15 of Set 6 | inhapim
# Processing Record 16 of Set 6 | quang ngai
# Processing Record 17 of Set 6 | tulun
# Processing Record 18 of Set 6 | mirante do paranapanema
# Processing Record 19 of Set 6 | altai
# Processing Record 20 of Set 6 | holdrege
# Processing Record 21 of Set 6 | monteagudo
# Processing Record 22 of Set 6 | tvoroyri
# Processing Record 23 of Set 6 | vila do maio
# Processing Record 24 of Set 6 | suva
# Processing Record 25 of Set 6 | shahrud
# Processing Record 26 of Set 6 | udachny
# Processing Record 27 of Set 6 | bunia
# Processing Record 28 of Set 6 | vilcun
# Processing Record 29 of Set 6 | wailua homesteads
# Processing Record 30 of Set 6 | new plymouth
# Processing Record 31 of Set 6 | morehead city
# Processing Record 32 of Set 6 | el alto
# Processing Record 33 of Set 6 | aracati
# Processing Record 34 of Set 6 | lompoc
# Processing Record 35 of Set 6 | kavaratti
# Processing Record 36 of Set 6 | punta arenas
# Processing Record 37 of Set 6 | baltasi
# Processing Record 38 of Set 6 | puerto ayora
# Processing Record 39 of Set 6 | ulety
# Processing Record 40 of Set 6 | guiyang
# Processing Record 41 of Set 6 | eraan
# Processing Record 42 of Set 6 | azare
# Processing Record 43 of Set 6 | kone
# Processing Record 44 of Set 6 | panorama
# Processing Record 45 of Set 6 | arkhangel'sk
# Processing Record 46 of Set 6 | farasan
# Processing Record 47 of Set 6 | lobva
# Processing Record 48 of Set 6 | tiznit
# Processing Record 49 of Set 6 | cascais
# Processing Record 50 of Set 6 | dunedin
# Processing Record 1 of Set 7 | hobyo
# Processing Record 2 of Set 7 | nouadhibou
# Processing Record 3 of Set 7 | dakhla
# Processing Record 4 of Set 7 | cabeceiras de basto
# Processing Record 5 of Set 7 | alice springs
# Processing Record 6 of Set 7 | cabo san lucas
# Processing Record 7 of Set 7 | petrov val
# Processing Record 8 of Set 7 | westport
# Processing Record 9 of Set 7 | hadibu
# Processing Record 10 of Set 7 | karatuzskoye
# Processing Record 11 of Set 7 | buala
# Processing Record 12 of Set 7 | codrington
# Processing Record 13 of Set 7 | vilyuchinsk
# Processing Record 14 of Set 7 | wakkanai
# Processing Record 15 of Set 7 | sanya
# Processing Record 16 of Set 7 | kanniyakumari
# Processing Record 17 of Set 7 | hithadhoo
# Processing Record 18 of Set 7 | aykhal
# Processing Record 19 of Set 7 | mahina
# Processing Record 20 of Set 7 | forster
# Processing Record 21 of Set 7 | benoni
# Processing Record 22 of Set 7 | impfondo
# Processing Record 23 of Set 7 | port lincoln
# Processing Record 24 of Set 7 | talacogon
# Processing Record 25 of Set 7 | fort-shevchenko
# Processing Record 26 of Set 7 | siping
# Processing Record 27 of Set 7 | balkanabat
# Processing Record 28 of Set 7 | gray
# Processing Record 29 of Set 7 | lerwick
# Processing Record 30 of Set 7 | kabompo
# Processing Record 31 of Set 7 | jibia
# Processing Record 32 of Set 7 | coquimbo
# Processing Record 33 of Set 7 | tomatlan
# Processing Record 34 of Set 7 | kill devil hills
# Processing Record 35 of Set 7 | villa gesell
# Processing Record 36 of Set 7 | ilha de mocambique
# Processing Record 37 of Set 7 | lazaro cardenas
# Processing Record 38 of Set 7 | pyetrykaw
# Processing Record 39 of Set 7 | zouerate
# Processing Record 40 of Set 7 | yeppoon
# Processing Record 41 of Set 7 | hasaki
# Processing Record 42 of Set 7 | bol
# Processing Record 43 of Set 7 | chunskiy
# Processing Record 44 of Set 7 | dalnegorsk
# Processing Record 45 of Set 7 | kerbakhiar
# Processing Record 46 of Set 7 | port saint john's
# Processing Record 47 of Set 7 | savaneta
# Processing Record 48 of Set 7 | stettler
# Processing Record 49 of Set 7 | port augusta
# Processing Record 50 of Set 7 | iida
# Processing Record 1 of Set 8 | maraba
# Processing Record 2 of Set 8 | antsiranana
# Processing Record 3 of Set 8 | bella vista
# Processing Record 4 of Set 8 | bamboo flat
# Processing Record 5 of Set 8 | papao
# Processing Record 6 of Set 8 | goulburn
# Processing Record 7 of Set 8 | peniche
# Processing Record 8 of Set 8 | atafu village
# Processing Record 9 of Set 8 | panacan
# Processing Record 10 of Set 8 | baihar
# Processing Record 11 of Set 8 | dompu
# Processing Record 12 of Set 8 | thompson
# Processing Record 13 of Set 8 | carnarvon
of Set 9 | alotau
# City not found. Skipping...
# Processing Record 37 of Set 9 | kaele
# Processing Record 38 of Set 9 | norton
# Processing Record 39 of Set 9 | belyy yar
# Processing Record 40 of Set 9 | mount gambier
# Processing Record 41 of Set 9 | dikhil
# Processing Record 42 of Set 9 | emerald
# Processing Record 43 of Set 9 | jati
# Processing Record 44 of Set 9 | moree
# Processing Record 45 of Set 9 | homer
# Processing Record 46 of Set 9 | perth
# Processing Record 47 of Set 9 | palopo
# Processing Record 48 of Set 9 | zhengzhou
# Processing Record 49 of Set 9 | glace bay
# Processing Record 50 of Set 9 | wuyishan
# Processing Record 1 of Set 10 | at taj
# Processing Record 2 of Set 10 | gelibolu
# Processing Record 3 of Set 10 | zhob
# Processing Record 4 of Set 10 | tateyama
# Processing Record 5 of Set 10 | klyuchi
# Processing Record 6 of Set 10 | nkurenkuru
# City not found. Skipping...
# Processing Record 7 of Set 10 | new norfolk
# Processing Record 8 of Set 10 | ola
# Processing Record 9 of Set 10 | mana
# Processing Record 10 of Set 10 | sorong
# Processing Record 11 of Set 10 | ayvacik
# Processing Record 12 of Set 10 | mme-bafumen
# Processing Record 13 of Set 10 | garden city
# Processing Record 14 of Set 10 | durazno
# Processing Record 15 of Set 10 | dzhambeyty
# Processing Record 16 of Set 10 | vorgashor
# Processing Record 17 of Set 10 | maharaganj
# Processing Record 18 of Set 10 | callao
# Processing Record 19 of Set 10 | san andres
# Processing Record 20 of Set 10 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 21 of Set 10 | afif
# Processing Record 22 of Set 10 | genhe
# Processing Record 23 of Set 10 | la sarre
# Processing Record 24 of Set 10 | choibalsan
# Processing Record 25 of Set 10 | benguela
# Processing Record 26 of Set 10 | nema
# Processing Record 27 of Set 10 | cabedelo
# Processing Record 28 of Set 10 | waddan
# Processing Record 29 of Set 10 | marang
# Processing Record 30 of Set 10 | sao joao da barra
# Processing Record 31 of Set 10 | san jose
# Processing Record 32 of Set 10 | tabou
# Processing Record 33 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 34 of Set 10 | salmas
# Processing Record 35 of Set 10 | flying fish cove
# Processing Record 36 of Set 10 | essaouira
# Processing Record 37 of Set 10 | luau
# Processing Record 38 of Set 10 | ndele
# Processing Record 39 of Set 10 | holyhead
# Processing Record 40 of Set 10 | barra de santo antonio
# Processing Record 41 of Set 10 | narasapur
# Processing Record 42 of Set 10 | gillette
# Processing Record 43 of Set 10 | lobito
# Processing Record 44 of Set 10 | helena-west helena
# Processing Record 45 of Set 10 | plouzane
# Processing Record 46 of Set 10 | taulaga
# Processing Record 47 of Set 10 | auki
# Processing Record 48 of Set 10 | vung tau
# Processing Record 49 of Set 10 | oyem
# Processing Record 50 of Set 10 | kyaikto
# Processing Record 1 of Set 11 | haiku-pauwela
# Processing Record 2 of Set 11 | horsham
# Processing Record 3 of Set 11 | el nido
# Processing Record 4 of Set 11 | jijel
# Processing Record 5 of Set 11 | ancud
# Processing Record 6 of Set 11 | urangan
# Processing Record 7 of Set 11 | kiunga
# Processing Record 8 of Set 11 | salalah
# Processing Record 9 of Set 11 | payande
# City not found. Skipping...
# Processing Record 10 of Set 11 | nacala
# Processing Record 11 of Set 11 | whangarei
# Processing Record 12 of Set 11 | baskil
# Processing Record 13 of Set 11 | bandar-e lengeh
# Processing Record 14 of Set 11 | general conesa
# Processing Record 15 of Set 11 | borba
# Processing Record 16 of Set 11 | bandarbeyla
# Processing Record 17 of Set 11 | port blair
# Processing Record 18 of Set 11 | hooper
# Processing Record 19 of Set 11 | secunderabad
# Processing Record 20 of Set 11 | windermere
# Processing Record 21 of Set 11 | guanica
# Processing Record 22 of Set 11 | milazzo
# Processing Record 23 of Set 11 | marsh harbour
# Processing Record 24 of Set 11 | nuuk
# Processing Record 25 of Set 11 | lethem
# Processing Record 26 of Set 11 | melo
# Processing Record 27 of Set 11 | prairie du chien
# Processing Record 28 of Set 11 | slave lake
# Processing Record 29 of Set 11 | ust'-barguzin
# Processing Record 30 of Set 11 | alva
# Processing Record 31 of Set 11 | lekki
# City not found. Skipping...
# Processing Record 32 of Set 11 | chulakkurgan
# Processing Record 33 of Set 11 | ouani
# Processing Record 34 of Set 11 | piti village
# Processing Record 35 of Set 11 | teshi old town
# Processing Record 36 of Set 11 | ploudalmezeau
# Processing Record 37 of Set 11 | sokoni
# Processing Record 38 of Set 11 | constantia
# Processing Record 39 of Set 11 | kargasok
# Processing Record 40 of Set 11 | ugoofaaru
# Processing Record 41 of Set 11 | fruita
# Processing Record 42 of Set 11 | enoch
# Processing Record 43 of Set 11 | jeju city
# Processing Record 44 of Set 11 | belmonte
# Processing Record 45 of Set 11 | butte
# Processing Record 46 of Set 11 | shenjiamen
# Processing Record 47 of Set 11 | basoko
# Processing Record 48 of Set 11 | tipasa
# Processing Record 49 of Set 11 | sona
# Processing Record 50 of Set 11 | valenca do piaui
# Processing Record 1 of Set 12 | karosta
# City not found. Skipping...
# Processing Record 2 of Set 12 | mount isa
# Processing Record 3 of Set 12 | weyburn
# Processing Record 4 of Set 12 | kargat
# Processing Record 5 of Set 12 | xiaoweizhai
# Processing Record 6 of Set 12 | uliastay
# Processing Record 7 of Set 12 | kununurra
# Processing Record 8 of Set 12 | greymouth
# Processing Record 9 of Set 12 | northam
# Processing Record 10 of Set 12 | ghat
# Processing Record 11 of Set 12 | fairdale
# Processing Record 12 of Set 12 | eureka
# Processing Record 13 of Set 12 | mugumu
# Processing Record 14 of Set 12 | kotel'va
# Processing Record 15 of Set 12 | kurchatov
# Processing Record 16 of Set 12 | mocorito
# Processing Record 17 of Set 12 | sittwe
# Processing Record 18 of Set 12 | kavarna
# Processing Record 19 of Set 12 | east london
# Processing Record 20 of Set 12 | mora
# Processing Record 21 of Set 12 | murashi
# Processing Record 22 of Set 12 | oppdal
# Processing Record 23 of Set 12 | urzhum
# Processing Record 24 of Set 12 | snoqualmie
# Processing Record 25 of Set 12 | jurby
# City not found. Skipping...
# Processing Record 26 of Set 12 | malango
# Processing Record 27 of Set 12 | villa el carmen
# Processing Record 28 of Set 12 | spassk-ryazanskiy
# Processing Record 29 of Set 12 | san bernardo
# Processing Record 30 of Set 12 | xining
# Processing Record 31 of Set 12 | kisangani
# Processing Record 32 of Set 12 | huruta
# Processing Record 33 of Set 12 | staryy dobrotvir
# Processing Record 34 of Set 12 | itoman
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
98# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    afaahiti -17.7500 -149.2833     28.93        83          87       10.96
# 1   madzhalis  42.1217   47.8333      4.40        93          95        1.52
# 2     ushuaia -54.8000  -68.3000      7.81        57           0        8.75
# 3  baardheere   2.3446   42.2764     28.57        53          72        4.05
# 4  bredasdorp -34.5322   20.0403     16.70        75           0        3.39
#
#   Country        Date
# 0      PF  1702243343
# 1      RU  1702243343
# 2      AR  1702243316
# 3      SO  1702243344
# 4      ZA  1702243344

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          afaahiti -17.7500 -149.2833     28.93        83          87
# 1         madzhalis  42.1217   47.8333      4.40        93          95
# 2           ushuaia -54.8000  -68.3000      7.81        57           0
# 3        baardheere   2.3446   42.2764     28.57        53          72
# 4        bredasdorp -34.5322   20.0403     16.70        75           0
#
#          Wind Speed Country        Date
# City_ID
# 0             10.96      PF  1702243343
# 1              1.52      RU  1702243343
# 2              8.75      AR  1702243316
# 3              4.05      SO  1702243344
# 4              3.39      ZA  1702243344

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(x = "Lat",
                  y = "Max Temp",
                  kind = "scatter",
                  edgecolors = "black",
                  s = 30
                 )

# Incorporate the other graph properties
plt.title(f"City Max Temperature vs. Latitude ({date.today()})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(x = "Lat",
                  y = "Humidity",
                  kind = "scatter",
                  edgecolors = "black",
                  s = 30
                 )

# Incorporate the other graph properties
plt.title(f"City Humidity vs. Latitude ({date.today()})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(x = "Lat",
                  y = "Cloudiness",
                  kind = "scatter",
                  edgecolors = "black",
                  s = 30
                 )

# Incorporate the other graph properties
plt.title(f"City Cloudiness vs. Latitude ({date.today()})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(x = "Lat",
                  y = "Wind Speed",
                  kind = "scatter",
                  edgecolors = "black",
                  s = 30
                 )

# Incorporate the other graph properties
plt.title(f"City Wind Speed vs. Latitude ({date.today()})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_plot(x_values, y_values, y_label, x_ann, y_ann):
    plt.scatter(x = x_values,
                y = y_values,
                s = 30
               )
    slope, intercept, r, p, ser = linregress(x_values, y_values)
    y_corr = slope * x_values + intercept
    plt.plot(x_values,
             y_corr,
             "r-"
            )
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.annotate(f'y = {round(slope, 2)}x + {round(intercept, 2)}',
                 (x_ann, y_ann),
                 color = "red",
                 size = 15
                )
    print(f'The r-value is: {r**2}')
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         madzhalis  42.1217   47.8333      4.40        93          95
# 3        baardheere   2.3446   42.2764     28.57        53          72
# 5        fort bragg  35.1390  -79.0060     22.12        83         100
# 9             sitka  57.0531 -135.3300      2.94        87          40
# 11             amga  60.8953  131.9608    -28.07        91         100
#
#          Wind Speed Country        Date
# City_ID
# 1              1.52      RU  1702243343
# 3              4.05      SO  1702243344
# 5              4.12      US  1702243345
# 9              3.09      US  1702243346
# 11             3.97      RU  1702243347

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              afaahiti -17.7500 -149.2833     28.93        83          87
# 2               ushuaia -54.8000  -68.3000      7.81        57           0
# 4            bredasdorp -34.5322   20.0403     16.70        75           0
# 6        port elizabeth -33.9180   25.5701     16.29        91           0
# 7             grytviken -54.2811  -36.5092      5.68        88         100
#
#          Wind Speed Country        Date
# City_ID
# 0             10.96      PF  1702243343
# 2              8.75      AR  1702243316
# 4              3.39      ZA  1702243344
# 6              1.03      ZA  1702243345
# 7              6.53      GS  1702243346

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_plot(northern_hemi_df["Lat"],
         northern_hemi_df["Max Temp"],
         "Max Temp",
         5,
         -30
        )
# Out:
# The r-value is: 0.6712664172695195

# %%
# Linear regression on Southern Hemisphere
lin_plot(southern_hemi_df["Lat"],
         southern_hemi_df["Max Temp"],
         "Max Temp",
         -50,
         30
        )
# Out:
# The r-value is: 0.49302104996760376

# %% [markdown]
# **Discussion about the linear relationship:**
#
# With the equator having Latitude 0, the further away from it you go, the temperature (and therefore Max Temp) will be cooler than at the equator. Since the Northern Hemisphere has latitudes that are positive, then the graph will have a downward trend. Similarly, with the Southern Hemiphere having negative latitudes, then the graph will have a negative trend.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_plot(northern_hemi_df["Lat"],
         northern_hemi_df["Humidity"],
         "Humidity",
         40,
         15
        )
# Out:
# The r-value is: 0.11595411971690056

# %%
# Southern Hemisphere
lin_plot(southern_hemi_df["Lat"],
         southern_hemi_df["Humidity"],
         "Humidity",
         -55,
         22
        )
# Out:
# The r-value is: 0.09619840604572748

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Since precipitation of some type (rain / ice / snow) occurs almost everywhere on the planet, the amount of humidity should not correlate to the latitude of the place on Earth. This can be seen by the low r-value for both graphs.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_plot(northern_hemi_df["Lat"],
         northern_hemi_df["Cloudiness"],
         "Cloudiness",
         40,
         10
        )
# Out:
# The r-value is: 0.07046278465958995

# %%
# Southern Hemisphere
lin_plot(southern_hemi_df["Lat"],
         southern_hemi_df["Cloudiness"],
         "Cloudiness",
         -55,
         35
        )
# Out:
# The r-value is: 0.031885581807957614

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Because clouds move with the wind and are created anywhere, the amount of cloudiness won't be related to the latitude of the city.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_plot(northern_hemi_df["Lat"],
         northern_hemi_df["Wind Speed"],
         "Wind Speed",
         10,
         12
        )
# Out:
# The r-value is: 0.021046037299493857

# %%
# Southern Hemisphere
lin_plot(southern_hemi_df["Lat"],
         southern_hemi_df["Wind Speed"],
         "Wind Speed",
         -30,
         11
        )
# Out:
# The r-value is: 0.03685805424581522

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The wind speed can vary at a location, depending on multiple factors, such as weather, cloud cover, temperature, etc. This means that it's not tied directly to the latitude of a location, which is verified by the very small r-values in both hemispheres.
