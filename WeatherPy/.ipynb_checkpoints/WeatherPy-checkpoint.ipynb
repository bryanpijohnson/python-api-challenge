# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=metric&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | shiqian
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | touros
# Processing Record 4 of Set 1 | aniva
# Processing Record 5 of Set 1 | plastun
# Processing Record 6 of Set 1 | borazjan
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | rabo de peixe
# Processing Record 10 of Set 1 | bilibino
# Processing Record 11 of Set 1 | klyuchi
# Processing Record 12 of Set 1 | calingasta
# Processing Record 13 of Set 1 | tazacorte
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | lago da pedra
# Processing Record 16 of Set 1 | margaret river
# Processing Record 17 of Set 1 | waitangi
# Processing Record 18 of Set 1 | haiku-pauwela
# Processing Record 19 of Set 1 | port lincoln
# Processing Record 20 of Set 1 | makassar
# Processing Record 21 of Set 1 | hawaiian paradise park
# Processing Record 22 of Set 1 | fort bragg
# Processing Record 23 of Set 1 | lihue
# Processing Record 24 of Set 1 | buala
# Processing Record 25 of Set 1 | margate
# Processing Record 26 of Set 1 | edinburgh of the seven seas
# Processing Record 27 of Set 1 | udachny
# Processing Record 28 of Set 1 | geraldton
# Processing Record 29 of Set 1 | ad darb
# Processing Record 30 of Set 1 | iskateley
# Processing Record 31 of Set 1 | naze
# Processing Record 32 of Set 1 | barra de santo antonio
# Processing Record 33 of Set 1 | portland
# Processing Record 34 of Set 1 | ouro preto do oeste
# Processing Record 35 of Set 1 | port isabel
# Processing Record 36 of Set 1 | blackmans bay
# Processing Record 37 of Set 1 | afaahiti
# Processing Record 38 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 39 of Set 1 | la cruz
# Processing Record 40 of Set 1 | kone
# Processing Record 41 of Set 1 | winnemucca
# Processing Record 42 of Set 1 | isafjordur
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | morondava
# Processing Record 45 of Set 1 | kizel
# Processing Record 46 of Set 1 | adamstown
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | raduzhnyy
# Processing Record 49 of Set 1 | san patricio
# Processing Record 50 of Set 1 | puerto natales
# Processing Record 0 of Set 2 | ilulissat
# Processing Record 1 of Set 2 | kaduy
# Processing Record 2 of Set 2 | iqaluit
# Processing Record 3 of Set 2 | vilyuchinsk
# Processing Record 4 of Set 2 | pospelikha
# Processing Record 5 of Set 2 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 6 of Set 2 | nogliki
# Processing Record 7 of Set 2 | kavala
# Processing Record 8 of Set 2 | ciechocinek
# Processing Record 9 of Set 2 | port saint john's
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | kolonia town
# Processing Record 12 of Set 2 | olonkinbyen
# Processing Record 13 of Set 2 | port mathurin
# Processing Record 14 of Set 2 | tabou
# Processing Record 15 of Set 2 | kapuskasing
# Processing Record 16 of Set 2 | nova vicosa
# Processing Record 17 of Set 2 | rio grande
# Processing Record 18 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 19 of Set 2 | cromer
# Processing Record 20 of Set 2 | mahina
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | beacon square
# Processing Record 23 of Set 2 | la'ie
# Processing Record 24 of Set 2 | uturoa
# Processing Record 25 of Set 2 | yemetsk
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 
of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 7 of Set 4 | shakawe
# Processing Record 8 of Set 4 | broken hill
# Processing Record 9 of Set 4 | sisimiut
# Processing Record 10 of Set 4 | queenstown
# Processing Record 11 of Set 4 | turpan
# Processing Record 12 of Set 4 | jatai
# Processing Record 13 of Set 4 | cheremushki
# Processing Record 14 of Set 4 | siniscola
# Processing Record 15 of Set 4 | puerto lempira
# Processing Record 16 of Set 4 | loralai
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | wailua homesteads
# Processing Record 19 of Set 4 | tsumeb
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | taoudenni
# Processing Record 22 of Set 4 | suining
# Processing Record 23 of Set 4 | marka
# Processing Record 24 of Set 4 | bull savanna
# Processing Record 25 of Set 4 | zheleznodorozhnyy
# Processing Record 26 of Set 4 | calchaqui
# Processing Record 27 of Set 4 | am djarass
# City not found. Skipping...
# Processing Record 28 of Set 4 | bulungu
# Processing Record 29 of Set 4 | fortuna
# Processing Record 30 of Set 4 | ulsteinvik
# Processing Record 31 of Set 4 | shimoda
# Processing Record 32 of Set 4 | kaiapoi
# Processing Record 33 of Set 4 | puerto armuelles
# Processing Record 34 of Set 4 | kapa'a
# Processing Record 35 of Set 4 | progreso
# Processing Record 36 of Set 4 | ak-suu
# Processing Record 37 of Set 4 | codrington
# Processing Record 38 of Set 4 | al-`ula
# City not found. Skipping...
# Processing Record 39 of Set 4 | sabzevar
# Processing Record 40 of Set 4 | mayqayyng
# Processing Record 41 of Set 4 | el zulia
# Processing Record 42 of Set 4 | konarka
# Processing Record 43 of Set 4 | morehead city
# Processing Record 44 of Set 4 | bubaque
# Processing Record 45 of Set 4 | abatskoye
# Processing Record 46 of Set 4 | zykovo
# Processing Record 47 of Set 4 | luanda
# Processing Record 48 of Set 4 | tandag
# Processing Record 49 of Set 4 | ciudad lazaro cardenas
# Processing Record 0 of Set 5 | howrah
# Processing Record 1 of Set 5 | kamaishi
# Processing Record 2 of Set 5 | dudinka
# Processing Record 3 of Set 5 | puerto ayora
# Processing Record 4 of Set 5 | palmer
# Processing Record 5 of Set 5 | aden
# Processing Record 6 of Set 5 | khash
# Processing Record 7 of Set 5 | kalmunai
# Processing Record 8 of Set 5 | callao
# Processing Record 9 of Set 5 | bikenibeu village
# Processing Record 10 of Set 5 | siewierz
# Processing Record 11 of Set 5 | atafu village
# Processing Record 12 of Set 5 | kasongo-lunda
# Processing Record 13 of Set 5 | kavaratti
# Processing Record 14 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 15 of Set 5 | dapchi
# Processing Record 16 of Set 5 | natal
# Processing Record 17 of Set 5 | itanhaem
# Processing Record 18 of Set 5 | smithers
# Processing Record 19 of Set 5 | lebu
# Processing Record 20 of Set 5 | port hedland
# Processing Record 21 of Set 5 | malabar
# Processing Record 22 of Set 5 | yorkton
# Processing Record 23 of Set 5 | tutoia
# Processing Record 24 of Set 5 | tazovsky
# Processing Record 25 of Set 5 | newport
# Processing Record 26 of Set 5 | bonthe
# Processing Record 27 of Set 5 | jiwani
# Processing Record 28 of Set 5 | mandal
# Processing Record 29 of Set 5 | tenabo
# Processing Record 30 of Set 5 | kenora
# Processing Record 31 of Set 5 | arawa
# Processing Record 32 of Set 5 | kerikeri
# Processing Record 33 of Set 5 | sona
# Processing Record 34 of Set 5 | badger
# Processing Record 35 of Set 5 | vila velha
# Processing Record 36 of Set 5 | tolanaro
# Processing Record 37 of Set 5 | ust-nera
# Processing Record 38 of Set 5 | jamestown
# Processing Record 39 of Set 5 | nemuro
# Processing Record 40 of Set 5 | aasiaat
# Processing Record 41 of Set 5 | hasaki
# Processing Record 42 of Set 5 | bambanglipuro
# Processing Record 43 of Set 5 | san carlos de bariloche
# Processing Record 44 of Set 5 | port elizabeth
# Processing Record 45 of Set 5 | carlinville
# Processing Record 46 of Set 5 | el bayadh
# Processing Record 47 of Set 5 | weiser
# Processing Record 48 of Set 5 | bereznik
# Processing Record 49 of Set 5 | bredasdorp
# Processing Record 0 of Set 6 | thinadhoo
# Processing Record 1 of Set 6 | rundu
# Processing Record 2 of Set 6 | la passe
# Processing Record 3 of Set 6 | ville platte
# Processing Record 4 of Set 6 | kruisfontein
# Processing Record 5 of Set 6 | kangding
# Processing Record 6 of Set 6 | paragould
# Processing Record 7 of Set 6 | acarau
# Processing Record 8 of Set 6 | dwarka
# Processing Record 9 of Set 6 | st. john's
# Processing Record 10 of Set 6 | invercargill
# Processing Record 11 of Set 6 | happy valley-goose bay
# Processing Record 12 of Set 6 | pemangkat
# Processing Record 13 of Set 6 | west island
# Processing Record 14 of Set 6 | vilyuysk
# Processing Record 15 of Set 6 | gajendragarh
# Processing Record 16 of Set 6 | nguigmi
# Processing Record 17 of Set 6 | kunming
# Processing Record 18 of Set 6 | port augusta
# Processing Record 19 of Set 6 | lincheng
# Processing Record 20 of Set 6 | lompoc
# Processing Record 21 of Set 6 | college
# Processing Record 22 of Set 6 | machecoul
# Processing Record 23 of Set 6 | kudahuvadhoo
# Processing Record 24 of Set 6 | howard springs
# Processing Record 25 of Set 6 | el maamoura
# Processing Record 26 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 27 of Set 6 | malango
# Processing Record 28 of Set 6 | island harbour
# Processing Record 29 of Set 6 | dehdasht
# Processing Record 30 of Set 6 | souillac
# Processing Record 31 of Set 6 | puerto san jose
# Processing Record 32 of Set 6 | praia da vitoria
# Processing Record 33 of Set 6 | vuktyl
# Processing Record 34 of Set 6 | weno
# Processing Record 35 of Set 6 | puerto baquerizo moreno
# Processing Record 36 of Set 6 | aksu
# Processing Record 37 of Set 6 | peskovka
# Processing Record 38 of Set 6 | abu jibeha
# Processing Record 39 of Set 6 | jiehu
# Processing Record 40 of Set 6 | thayetmyo
# Processing Record 41 of Set 6 | yuzhno-kurilsk
# Processing Record 42 of Set 6 | obo
# Processing Record 43 of Set 6 | sydney
# Processing Record 44 of Set 6 | ketchikan
# Processing Record 45 of Set 6 | caleta de carquin
# Processing Record 46 of Set 6 | port-vila
# Processing Record 47 of Set 6 | san antonio de pale
# Processing Record 48 of Set 6 | constantia
# Processing Record 49 of Set 6 | novaya igirma
# Processing Record 46 of Set 9 | raj-nandgaon
# Processing Record 47 of Set 9 | salekhard
# Processing Record 48 of Set 9 | takoradi
# Processing Record 49 of Set 9 | bandon
# Processing Record 0 of Set 10 | tianpeng
# Processing Record 1 of Set 10 | penzance
# Processing Record 2 of Set 10 | sao vicente
# Processing Record 3 of Set 10 | leava
# Processing Record 4 of Set 10 | vila do maio
# Processing Record 5 of Set 10 | loango
# Processing Record 6 of Set 10 | susuman
# Processing Record 7 of Set 10 | porto velho
# Processing Record 8 of Set 10 | port douglas
# Processing Record 9 of Set 10 | narail
# Processing Record 10 of Set 10 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 11 of Set 10 | abepura
# Processing Record 12 of Set 10 | mount pearl
# Processing Record 13 of Set 10 | gulf shores
# Processing Record 14 of Set 10 | cabedelo
# Processing Record 15 of Set 10 | puerto el triunfo
# Processing Record 16 of Set 10 | al ghayzah
# Processing Record 17 of Set 10 | dovzhansk
# City not found. Skipping...
# Processing Record 18 of Set 10 | lamu
# Processing Record 19 of Set 10 | katsuura
# Processing Record 20 of Set 10 | villavicencio
# Processing Record 21 of Set 10 | ilabaya
# Processing Record 22 of Set 10 | ola
# Processing Record 23 of Set 10 | dakhla
# Processing Record 24 of Set 10 | salina
# Processing Record 25 of Set 10 | aykol
# City not found. Skipping...
# Processing Record 26 of Set 10 | quellon
# Processing Record 27 of Set 10 | ozery
# Processing Record 28 of Set 10 | ponca city
# Processing Record 29 of Set 10 | bodo
# Processing Record 30 of Set 10 | burang
# Processing Record 31 of Set 10 | lepsy
# Processing Record 32 of Set 10 | khandyga
# Processing Record 33 of Set 10 | springbok
# Processing Record 34 of Set 10 | lanivtsi
# Processing Record 35 of Set 10 | kingori
# Processing Record 36 of Set 10 | laguna
# Processing Record 37 of Set 10 | singarayakonda
# Processing Record 38 of Set 10 | birjand
# Processing Record 39 of Set 10 | djibo
# Processing Record 40 of Set 10 | cradock
# Processing Record 41 of Set 10 | tual
# Processing Record 42 of Set 10 | goderich
# Processing Record 43 of Set 10 | ust'-ilimsk
# Processing Record 44 of Set 10 | childress
# Processing Record 45 of Set 10 | marumori
# Processing Record 46 of Set 10 | namibe
# Processing Record 47 of Set 10 | lotoshino
# Processing Record 48 of Set 10 | inari
# Processing Record 49 of Set 10 | la huaca
# Processing Record 0 of Set 11 | prince rupert
# Processing Record 1 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 2 of Set 11 | sangju
# Processing Record 3 of Set 11 | urzhar
# Processing Record 4 of Set 11 | gore
# Processing Record 5 of Set 11 | carnot
# Processing Record 6 of Set 11 | illapel
# Processing Record 7 of Set 11 | yamethin
# Processing Record 8 of Set 11 | arteche
# Processing Record 9 of Set 11 | oltinko'l
# Processing Record 10 of Set 11 | langon
# Processing Record 11 of Set 11 | quezon
# Processing Record 12 of Set 11 | khorixas
# Processing Record 13 of Set 11 | wynyard
# Processing Record 14 of Set 11 | colonia
# Processing Record 15 of Set 11 | la mira
# Processing Record 16 of Set 11 | mildura
# Processing Record 17 of Set 11 | mount isa
# Processing Record 18 of Set 11 | arno
# Processing Record 19 of Set 11 | alghero
# Processing Record 20 of Set 11 | arraial do cabo
# Processing Record 21 of Set 11 | changyon
# Processing Record 22 of Set 11 | mukalla
# Processing Record 23 of Set 11 | libreville
# Processing Record 24 of Set 11 | argo
# Processing Record 25 of Set 11 | nagqu
# Processing Record 26 of Set 11 | tarija
# Processing Record 27 of Set 11 | banda aceh
# Processing Record 28 of Set 11 | xinqing
# Processing Record 29 of Set 11 | newman
# Processing Record 30 of Set 11 | esfarayen
# Processing Record 31 of Set 11 | pitimbu
# Processing Record 32 of Set 11 | altinekin
# Processing Record 33 of Set 11 | strugi-krasnyye
# Processing Record 34 of Set 11 | san sebastian de la gomera
# Processing Record 35 of Set 11 | lata
# Processing Record 36 of Set 11 | fannuj
# City not found. Skipping...
# Processing Record 37 of Set 11 | berezovyy
# Processing Record 38 of Set 11 | punta del este
# Processing Record 39 of Set 11 | labrador city
# Processing Record 40 of Set 11 | dean funes
# Processing Record 41 of Set 11 | kulia village
# City not found. Skipping...
# Processing Record 42 of Set 11 | nevel'sk
# Processing Record 43 of Set 11 | kaohsiung
# Processing Record 44 of Set 11 | koungou
# Processing Record 45 of Set 11 | mogocha
# Processing Record 46 of Set 11 | pisco
# Processing Record 47 of Set 11 | aldan
# Processing Record 48 of Set 11 | tamanrasset
# Processing Record 49 of Set 11 | rongelap
# Processing Record 0 of Set 12 | naryn
# Processing Record 1 of Set 12 | fernley
# Processing Record 2 of Set 12 | vredenburg
# City not found. Skipping...
# Processing Record 3 of Set 12 | nagamangala
# Processing Record 4 of Set 12 | bayan
# Processing Record 5 of Set 12 | gillette
# Processing Record 6 of Set 12 | oyama
# Processing Record 7 of Set 12 | falmouth
# Processing Record 8 of Set 12 | ampanihy
# Processing Record 9 of Set 12 | luorong
# Processing Record 10 of Set 12 | tyre
# Processing Record 11 of Set 12 | camacupa
# Processing Record 12 of Set 12 | floreffe
# Processing Record 13 of Set 12 | natchez
# Processing Record 14 of Set 12 | lorengau
# Processing Record 15 of Set 12 | selfoss
# Processing Record 16 of Set 12 | hun
# Processing Record 17 of Set 12 | taradale
# Processing Record 18 of Set 12 | hibbing
# Processing Record 19 of Set 12 | flin flon
# Processing Record 20 of Set 12 | yeniseysk
# Processing Record 21 of Set 12 | fuling
# Processing Record 22 of Set 12 | kristiansund
# Processing Record 23 of Set 12 | lubang
# Processing Record 24 of Set 12 | monmouth
# Processing Record 25 of Set 12 | tofol
# Processing Record 26 of Set 12 | tomatlan
# Processing Record 27 of Set 12 | xindi
# Processing Record 28 of Set 12 | leirvik
# Processing Record 29 of Set 12 | arys
# Processing Record 30 of Set 12 | pak chong
# Processing Record 31 of Set 12 | bismarck
# Processing Record 32 of Set 12 | plouguerneau
# Processing Record 33 of Set 12 | owando
# Processing Record 34 of Set 12 | cassilandia
# Processing Record 35 of Set 12 | malindi
# Processing Record 36 of Set 12 | villa ojo de agua
# Processing Record 37 of Set 12 | armacao de buzios
# Processing Record 38 of Set 12 | masterton
# Processing Record 39 of Set 12 | karachi
# Processing Record 40 of Set 12 | ivins
# Processing Record 41 of Set 12 | sinabang
# Processing Record 42 of Set 12 | ebon
# Processing Record 43 of Set 12 | yarovoye
# Processing Record 44 of Set 12 | el paso
# Processing Record 45 of Set 12 | nadi
# Processing Record 46 of Set 12 | palikir - national government center
# Processing Record 47 of Set 12 | greenland
# Processing Record 48 of Set 12 | siwa oasis
# Processing Record 49 of Set 12 | princeville
# Processing Record 0 of Set 13 | lagos
# Processing Record 1 of Set 13 | 'izbat al burj
# City not found. Skipping...
# Processing Record 2 of Set 13 | denbigh
# Processing Record 3 of Set 13 | novouzensk
# Processing Record 4 of Set 13 | panjab
# Processing Record 5 of Set 13 | coihueco
# Processing Record 6 of Set 13 | barcelos
# Processing Record 7 of Set 13 | gretna
# Processing Record 8 of Set 13 | andovoranto
# Processing Record 9 of Set 13 | punta arenas
# Processing Record 10 of Set 13 | alipur duar
# City not found. Skipping...
# Processing Record 11 of Set 13 | ziro
# Processing Record 12 of Set 13 | vernon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
98# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    shiqian  27.5225  108.2281     16.41        96          99        1.49
# 1  grytviken -54.2811  -36.5092      3.40        85          32        4.73
# 2     touros  -5.1989  -35.4608     26.62        75          97        7.66
# 3      aniva  46.7144  142.5294     -5.94        68          82        9.48
# 4    plastun  44.7561  136.2939    -13.25        50           0        6.06
#
#   Country        Date
# 0      CN  1702157432
# 1      GS  1702157432
# 2      BR  1702157433
# 3      RU  1702157433
# 4      RU  1702157434

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          shiqian  27.5225  108.2281     16.41        96          99
# 1        grytviken -54.2811  -36.5092      3.40        85          32
# 2           touros  -5.1989  -35.4608     26.62        75          97
# 3            aniva  46.7144  142.5294     -5.94        68          82
# 4          plastun  44.7561  136.2939    -13.25        50           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.49      CN  1702157432
# 1              4.73      GS  1702157432
# 2              7.66      BR  1702157433
# 3              9.48      RU  1702157433
# 4              6.06      RU  1702157434

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(x = "Lat",
                  y = "Max Temp",
                  kind = "scatter",
                  edgecolors = "black",
                  s = 30
                 )

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2023-12-09)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(x = "Lat",
                  y = "Humidity",
                  kind = "scatter",
                  edgecolors = "black",
                  s = 30
                 )

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2023-12-09)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(x = "Lat",
                  y = "Cloudiness",
                  kind = "scatter",
                  edgecolors = "black",
                  s = 30
                 )

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness ()")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(x = "Lat",
                  y = "Wind Speed",
                  kind = "scatter",
                  edgecolors = "black",
                  s = 30
                 )

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2023-12-09)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_plot(x_values, y_values, y_label, x_ann, y_ann):
    plt.scatter(x = x_values,
                y = y_values,
                s = 30
               )
    slope, intercept, r, p, ser = linregress(x_values, y_values)
    y_corr = slope * x_values + intercept
    plt.plot(x_values,
             y_corr,
             "r-"
            )
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.annotate(f'y = {round(slope, 2)}x + {round(intercept, 2)}',
                 (x_ann, y_ann),
                 color = "red",
                 size = 15
                )
    print(f'The r-value is: {r**2}')
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         shiqian  27.5225  108.2281     16.41        96          99
# 3           aniva  46.7144  142.5294     -5.94        68          82
# 4         plastun  44.7561  136.2939    -13.25        50           0
# 5        borazjan  29.2666   51.2159     20.39        44           1
# 6          bethel  41.3712  -73.4140     11.22        80           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.49      CN  1702157432
# 3              9.48      RU  1702157433
# 4              6.06      RU  1702157434
# 5              1.42      IR  1702157435
# 6              0.00      US  1702157215

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                grytviken -54.2811 -36.5092      3.40        85          32
# 2                   touros  -5.1989 -35.4608     26.62        75          97
# 11              calingasta -31.3308 -69.4078     26.86        30           0
# 13       port-aux-francais -49.3500  70.2167      3.34        76          79
# 14           lago da pedra  -4.3333 -45.1667     28.12        65         100
#
#          Wind Speed Country        Date
# City_ID
# 1              4.73      GS  1702157432
# 2              7.66      BR  1702157433
# 11             7.33      AR  1702157437
# 13            11.06      TF  1702157438
# 14             3.24      BR  1702157438

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_plot(northern_hemi_df["Lat"],
         northern_hemi_df["Max Temp"],
         "Max Temp",
         5,
         -30
        )
# Out:
# The r-value is: 0.7209091117797803

# %%
# Linear regression on Southern Hemisphere
lin_plot(southern_hemi_df["Lat"],
         southern_hemi_df["Max Temp"],
         "Max Temp",
         -50,
         30
        )
# Out:
# The r-value is: 0.48634655988028785

# %% [markdown]
# **Discussion about the linear relationship:**
#
# With the equator having Latitude 0, the further away from it you go, the temperature (and therefore Max Temp) will be cooler than at the equator. Since the Northern Hemisphere has latitudes that are positive, then the graph will have a downward trend. Similarly, with the Southern Hemiphere having negative latitudes, then the graph will have a negative trend.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_plot(northern_hemi_df["Lat"],
         northern_hemi_df["Humidity"],
         "Humidity",
         40,
         15
        )
# Out:
# The r-value is: 0.09325690528214518

# %%
# Southern Hemisphere
lin_plot(southern_hemi_df["Lat"],
         southern_hemi_df["Humidity"],
         "Humidity",
         -55,
         22
        )
# Out:
# The r-value is: 0.09854239829176628

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Since precipitation of some type (rain / ice / snow) occurs almost everywhere on the planet, the amount of humidity should not correlate to the latitude of the place on Earth. This can be seen by the low r-value for both graphs.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_plot(northern_hemi_df["Lat"],
         northern_hemi_df["Cloudiness"],
         "Cloudiness",
         40,
         10
        )
# Out:
# The r-value is: 0.059040089939382145

# %%
# Southern Hemisphere
lin_plot(southern_hemi_df["Lat"],
         southern_hemi_df["Cloudiness"],
         "Cloudiness",
         -55,
         35
        )
# Out:
# The r-value is: 0.019146394744943177

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Because clouds move with the wind and are created anywhere, the amount of cloudiness won't be related to the latitude of the city.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_plot(northern_hemi_df["Lat"],
         northern_hemi_df["Wind Speed"],
         "Wind Speed",
         10,
         12
        )
# Out:
# The r-value is: 0.0064686801349532735

# %%
# Southern Hemisphere
lin_plot(southern_hemi_df["Lat"],
         southern_hemi_df["Wind Speed"],
         "Wind Speed",
         -30,
         11
        )
# Out:
# The r-value is: 0.07111674181721453

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The wind speed can vary at a location, depending on multiple factors, such as weather, cloud cover, temperature, etc. This means that it's not tied directly to the latitude of a location, which is verified by the very small r-values in both hemispheres.
